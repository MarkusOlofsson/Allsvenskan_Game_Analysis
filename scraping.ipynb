# %%
import requests

# %%
standings_url = "https://fbref.com/en/comps/29/Allsvenskan-Stats"

# %%
data = requests.get(standings_url) #laddar ner html filen av sidan

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(data.text)

# %%
standings_table = soup.select('table.stats_table')[0]

# %%
links = standings_table.find_all('a')

# %%
links = [l.get("href") for l in links]

# %%
links = [l for l in links if '/squads/' in l]

# %%
team_urls = [f"https://fbref.com{l}" for l in links]

# %%
team_urls
# Out:
# ['https://fbref.com/en/squads/f3d8c8b9/2024/Malmo-Stats',
#  'https://fbref.com/en/squads/92bfd7f0/Hammarby-Stats',
#  'https://fbref.com/en/squads/b0333581/AIK-Stockholm-Stats',
#  'https://fbref.com/en/squads/9423c05a/2024/Djurgarden-Stats',
#  'https://fbref.com/en/squads/b1a7a7b9/Mjallby-Stats',
#  'https://fbref.com/en/squads/7c2d1adb/GAIS-Stats',
#  'https://fbref.com/en/squads/50e85bfc/2024/Elfsborg-Stats',
#  'https://fbref.com/en/squads/8774e267/2024/Hacken-Stats',
#  'https://fbref.com/en/squads/e9d60d0c/Sirius-Stats',
#  'https://fbref.com/en/squads/bb9e11b2/Brommapojkarna-Stats',
#  'https://fbref.com/en/squads/1d0836d6/Norrkoping-Stats',
#  'https://fbref.com/en/squads/17366e53/Halmstad-Stats',
#  'https://fbref.com/en/squads/ef1ab26a/Goteborg-Stats',
#  'https://fbref.com/en/squads/d048ed60/Varnamo-Stats',
#  'https://fbref.com/en/squads/9f13771c/Kalmar-Stats',
#  'https://fbref.com/en/squads/a8481ab9/Vasteras-Stats']

# %%
team_url = team_urls[0]

# %%
data = requests.get(team_url)

# %%
import pandas as pd

# %%
matches = pd.read_html(data.text, match="Scores & Fixtures")
# Out:
# C:\Users\marku\AppData\Local\Temp\ipykernel_48044\1970929637.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")

# %%
matches[0]
# Out:
#           Date   Time         Comp         Round  Day Venue Result  GF  GA  \
# 0   2024-03-30  15:00  Allsvenskan   Matchweek 1  Sat  Away      W   5   1
# 1   2024-04-07  14:00  Allsvenskan   Matchweek 2  Sun  Home      W   2   0
# 2   2024-04-15  19:00  Allsvenskan   Matchweek 3  Mon  Away      W   4   0
# 3   2024-04-20  17:30  Allsvenskan   Matchweek 4  Sat  Home      W   1   0
# 4   2024-04-25  19:00  Allsvenskan   Matchweek 5  Thu  Away      W   1   0
# 5   2024-04-28  14:00  Allsvenskan   Matchweek 6  Sun  Home      W   5   0
# 6   2024-05-05  14:00  Allsvenskan   Matchweek 7  Sun  Away      L   1   3
# 7   2024-05-13  19:10  Allsvenskan   Matchweek 8  Mon  Away      W   3   0
# 8   2024-05-16  19:00  Allsvenskan   Matchweek 9  Thu  Home      W   1   0
# 9   2024-05-20  19:10  Allsvenskan  Matchweek 10  Mon  Away      D   2   2
# 10  2024-05-24  19:00  Allsvenskan  Matchweek 11  Fri  Home      W   5   0
# ...

# %%
soup = BeautifulSoup(data.text)

# %%
links = soup.find_all('a')

# %%
links = [l.get("href") for l in links]

# %%
links = [ l for l in links if l and 'all_comps/shooting/' in l]

# %%
data = requests.get(f"https://fbref.com{links[0]}")

# %%
shooting = pd.read_html(data.text, match="Shooting")[0]
# Out:
# C:\Users\marku\AppData\Local\Temp\ipykernel_48044\2517714723.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match="Shooting")[0]

# %%
shooting.head()
# Out:
#     For Malmö                                                               \
#          Date   Time         Comp        Round  Day Venue Result   GF   GA
# 0  2024-03-30  15:00  Allsvenskan  Matchweek 1  Sat  Away      W  5.0  1.0
# 1  2024-04-07  14:00  Allsvenskan  Matchweek 2  Sun  Home      W  2.0  0.0
# 2  2024-04-15  19:00  Allsvenskan  Matchweek 3  Mon  Away      W  4.0  0.0
# 3  2024-04-20  17:30  Allsvenskan  Matchweek 4  Sat  Home      W  1.0  0.0
# 4  2024-04-25  19:00  Allsvenskan  Matchweek 5  Thu  Away      W  1.0  0.0
#
#               Standard                                          \
#      Opponent      Gls  Sh SoT  SoT%  G/Sh G/SoT Dist PK PKatt
# 0  Norrköping        5  22   7  31.8  0.23  0.71  NaN  0     0
# 1    Hammarby        2  23   8  34.8  0.09  0.25  NaN  0     0
# 2     Värnamo        4  14   9  64.3  0.29  0.44  NaN  0     0
# 3    Västerås        1  19  11  57.9  0.05  0.09  NaN  0     0
# ...

# %%
shooting.columns = shooting.columns.droplevel()

# %%
shooting.head()
# Out:
#          Date   Time         Comp        Round  Day Venue Result   GF   GA  \
# 0  2024-03-30  15:00  Allsvenskan  Matchweek 1  Sat  Away      W  5.0  1.0
# 1  2024-04-07  14:00  Allsvenskan  Matchweek 2  Sun  Home      W  2.0  0.0
# 2  2024-04-15  19:00  Allsvenskan  Matchweek 3  Mon  Away      W  4.0  0.0
# 3  2024-04-20  17:30  Allsvenskan  Matchweek 4  Sat  Home      W  1.0  0.0
# 4  2024-04-25  19:00  Allsvenskan  Matchweek 5  Thu  Away      W  1.0  0.0
#
#      Opponent  Gls  Sh  SoT  SoT%  G/Sh  G/SoT  Dist  PK  PKatt  Match Report
# 0  Norrköping    5  22    7  31.8  0.23   0.71   NaN   0      0  Match Report
# 1    Hammarby    2  23    8  34.8  0.09   0.25   NaN   0      0  Match Report
# 2     Värnamo    4  14    9  64.3  0.29   0.44   NaN   0      0  Match Report
# 3    Västerås    1  19   11  57.9  0.05   0.09   NaN   0      0  Match Report
# 4  Djurgården    1  11    4  36.4  0.09   0.25   NaN   0      0  Match Report

# %%
team_data = matches[0].merge(shooting[["Date", "Sh", "SoT", "Dist", "PK", "PKatt"]], on="Date")

# %%
years = list(range(2024, 2021, -1))

# %%
years #Vilka år vi vill se historisk data från
# Out:
# [2024, 2023, 2022]

# %%
all_matches = []

# %%
standings_url = "https://fbref.com/en/comps/29/Allsvenskan-Stats"

# %%
import time

for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]

    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"

    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")

        data = requests.get(team_url)
        matches = pd.read_html(data.text, match="Scores & Fixtures")[0]

        soup = BeautifulSoup(data.text)
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        data = requests.get(f"https://fbref.com{links[0]}")
        shooting = pd.read_html(data.text, match="Shooting")[0]
        shooting.columns = shooting.columns.droplevel()

        try: 
            team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "PK", "PKatt"]], on="Date")
        except ValueError:
            continue

        team_data = team_data[team_data["Comp"] == "Allsvenskan"]
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(2)
# Out:
# C:\Users\marku\AppData\Local\Temp\ipykernel_48044\558903332.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# C:\Users\marku\AppData\Local\Temp\ipykernel_48044\558903332.py:25: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match="Shooting")[0]
# C:\Users\marku\AppData\Local\Temp\ipykernel_48044\558903332.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
# ...

# %%
match_df = pd.concat(all_matches)

# %%
match_df.columns = [c.lower() for c in match_df.columns]

# %%
match_df.to_csv("matcheslatest.csv")

# %%
match_df
# Out:
#           date   time         comp         round  day venue result  gf  ga  \
# 0   2024-03-30  15:00  Allsvenskan   Matchweek 1  Sat  Away      W   5   1
# 1   2024-04-07  14:00  Allsvenskan   Matchweek 2  Sun  Home      W   2   0
# 2   2024-04-15  19:00  Allsvenskan   Matchweek 3  Mon  Away      W   4   0
# 3   2024-04-20  17:30  Allsvenskan   Matchweek 4  Sat  Home      W   1   0
# 4   2024-04-25  19:00  Allsvenskan   Matchweek 5  Thu  Away      W   1   0
# ..         ...    ...          ...           ...  ...   ...    ...  ..  ..
# 25  2022-10-15  15:00  Allsvenskan  Matchweek 26  Sat  Away      L   1   4
# 26  2022-10-19  19:00  Allsvenskan  Matchweek 27  Wed  Home      L   1   2
# 27  2022-10-24  19:00  Allsvenskan  Matchweek 28  Mon  Away      L   0   4
# 28  2022-10-30  15:00  Allsvenskan  Matchweek 29  Sun  Home      L   2   3
# 29  2022-11-06  15:00  Allsvenskan  Matchweek 30  Sun  Away      L   0   4
#
# ...
